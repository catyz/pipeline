# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from toast.tod.sim_focalplane import plot_focalplane
import sqlite3
import toast.qarray as qa

# %%
fp = pd.read_pickle('focalplane.pkl')

# %%
detnames = list(fp.keys())
dets = {x: fp[x]['quat'] for x in detnames}
detpolcol = {x: "red" if i % 2 == 0 else "blue" for i, x in enumerate(detnames)}
detfwhm = {x: fp[x]['fhwm'] for x in detnames}

# %%
plot_focalplane(dets, 5, 5, None, fwhm = detfwhm, polcolor=detpolcol)
